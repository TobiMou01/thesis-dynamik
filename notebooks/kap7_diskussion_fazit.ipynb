# %% [markdown]
# # Kapitel 7 — Diskussion und Fazit
#
# Synthese-Notebook. Re-Used Outputs aus Kap. 4–6 für die finale Diskussion und das Fazit.
# Das Kapitel selbst ist primär Fließtext; Tabellen/Plots werden hier nur dort gebaut, wo
# ein zusammenfassender Vergleich (z.B. eigene Befunde vs. Literatur) visualisiert werden soll.

# %%
# Setup
import sys
from pathlib import Path

# src/ in den Pfad legen, damit Helper importierbar sind
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy import stats

import analysis_helpers as ah
from analysis_helpers import (
    RATIO_ORDER, RATIO_LABEL, RATIO_LAYER, SECTOR_ORDER,
)

# Plot-Defaults — konsistent über alle Notebooks
plt.rcParams.update({
    "font.family": "DejaVu Sans", "font.size": 10,
    "axes.titlesize": 11, "axes.labelsize": 10,
    "xtick.labelsize": 9, "ytick.labelsize": 9, "legend.fontsize": 9,
    "figure.dpi": 110, "savefig.dpi": 150, "savefig.bbox": "tight",
    "axes.spines.top": False, "axes.spines.right": False,
})

# Schichtfarben (konsistent mit DOCX-Plots)
LAYER_COLORS = {
    "Profitabilität":  "#2C5F8D",
    "Liquidität":      "#7FB069",
    "Kapitalstruktur": "#C75D4F",
}
QUAD_COLORS = {
    "KORREKTIV-STABIL":   "#1F77B4",
    "KORREKTIV-VOLATIL":  "#D62728",
    "PERSISTENT-STABIL":  "#2CA02C",
    "PERSISTENT-VOLATIL": "#FF7F0E",
}

print("Setup OK — analysis_helpers geladen.")
# Out:
# Setup OK — analysis_helpers geladen.

# %% [markdown]
# ---
# ## 7.1 Ökonomische Interpretation der Befunde
#
# *Hauptsächlich Fließtext*

# %% [markdown]
# ---
# ## 7.2 Einordnung in die Literatur

# %% [markdown]
# ### 7.2.1 Vergleich mit Dichev & Tang (2009)

# %%
# Eigene Halblebensdauern aus τ-Formel
summary = ah.add_halflife_columns(ah.load_ar_summary())
summary[["ratio","phi1_median","hl_quarters_tau","hl_years_tau"]]
# Out:
#             ratio  phi1_median  hl_quarters_tau  hl_years_tau
# 0     EBIT_margin      -0.4309           1.2296        0.3074
# 1             ROA      -0.4315           1.2273        0.3068
# 2             ROE      -0.4274           1.2432        0.3108
# 3   current_ratio      -0.1737           3.6329        0.9082
# 4  debt_to_equity      -0.0894           7.4013        1.8503
# 5    equity_ratio      -0.0398          17.0668        4.2667
# 6      fcf_margin      -0.4586           1.1296        0.2824

# %% [markdown]
# ### 7.2.2 Vergleich mit Lemmon, Roberts & Zender (2008)
#
# *Manuelle Tabelle: eigene EK-Quote-t½ vs. Literatur*

# %% [markdown]
# ---
# ## 7.3 Limitationen
#
# *Fließtext*

# %% [markdown]
# ---
# ## 7.4 Praktische Implikationen
#
# *Fließtext*

# %% [markdown]
# ---
# # Kapitel 8 — Fazit und Ausblick

# %% [markdown]
# ## 8.1 Zusammenfassung der Ergebnisse
#
# *Fließtext*

# %% [markdown]
# ## 8.2 Wissenschaftlicher Beitrag
#
# *Fließtext*

# %% [markdown]
# ## 8.3 Ausblick
#
# *Fließtext*
